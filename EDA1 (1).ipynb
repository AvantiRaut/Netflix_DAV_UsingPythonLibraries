# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('ott.csv')

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                   NaN            NaN
# 4     Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# ...                                                 ...            ...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#               date_added  release_year rating   duration  \
# 0     September 25, 2021          2020  PG-13     90 min
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# 2     September 24, 2021          2021  TV-MA   1 Season
# 3     September 24, 2021          2021  TV-MA   1 Season
# 4     September 24, 2021          2021  TV-MA  2 Seasons
# ...                  ...           ...    ...        ...
# 8802   November 20, 2019          2007      R    158 min
# 8803        July 1, 2019          2018  TV-Y7  2 Seasons
# 8804    November 1, 2019          2009      R     88 min
# 8805    January 11, 2020          2006     PG     88 min
# 8806       March 2, 2019          2015  TV-14    111 min
#
#                                               listed_in  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2     Crime TV Shows, International TV Shows, TV Act...
# 3                                Docuseries, Reality TV
# 4     International TV Shows, Romantic TV Shows, TV ...
# ...                                                 ...
# 8802                     Cult Movies, Dramas, Thrillers
# 8803             Kids' TV, Korean TV Shows, TV Comedies
# 8804                            Comedies, Horror Movies
# 8805                 Children & Family Movies, Comedies
# 8806     Dramas, International Movies, Music & Musicals
#
#                                             description
# 0     As her father nears the end of his life, filmm...
# 1     After crossing paths at a party, a Cape Town t...
# 2     To protect his family from a powerful drug lor...
# 3     Feuds, flirtations and toilet talk go down amo...
# 4     In a city of coaching centers known to train I...
# ...                                                 ...
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...
#
# [8807 rows x 12 columns]

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# 8804   November 1, 2019          2009      R     88 min
# 8805   January 11, 2020          2006     PG     88 min
# 8806      March 2, 2019          2015  TV-14    111 min
#
#                                            listed_in  \
# 8802                  Cult Movies, Dramas, Thrillers
# 8803          Kids' TV, Korean TV Shows, TV Comedies
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8802  A political cartoonist, a crime reporter and a...
# 8803  While living alone in a spooky town, a young g...
# 8804  Looking to survive in a world taken over by zo...
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df.rename(columns={'listed_in':'genre'},inplace=True)
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %% [markdown]
# Dropping the show_id column as it may be of no use in the analysis

# %%
df.drop(columns='show_id',inplace=True)

# %% [markdown]
# Checking for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique().sort_values(ascending=False)
# Out:
# title           8807
# description     8775
# cast            7692
# director        4528
# date_added      1767
# country          748
# genre            514
# duration         220
# release_year      74
# rating            17
# type               2
# dtype: int64

# %%
null = df.isna().sum().sort_values(ascending=False)
percent = round(df.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                    ',missing_data['Missing Value Count'].sum(),'      ',round(100*(missing_data['Missing Value Count'].sum()/df.shape[0]),2))
# Out:
# Total Records Present:  8807
#             Missing Value Count  Percentage
# director                   2634       29.91
# country                     831        9.44
# cast                        825        9.37
# date_added                   10        0.11
# rating                        4        0.05
# duration                      3        0.03
# Total                      4307        48.9

# %%
df.dropna(subset = ['date_added'],inplace=True)
df['date_added'].isna().sum()
# Out:
# 0

# %% [markdown]
# Dropping the rows which have null values in rating column as there are only 4 values which sums up to only 0.05% of the total values

# %%
df.dropna(subset = ['rating'],inplace=True)
df['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# Dropping the rows which have null values in duration column as there are only 3 values which sums up to only 0.03% of the total values

# %%
df.dropna(subset = ['duration'],inplace=True)
df['rating'].isna().sum()
# Out:
# 0

# %%
null = df.isna().sum().sort_values(ascending=False)
percent = round(df.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                  ',missing_data['Missing Value Count'].sum(),'     ',round(100*(missing_data['Missing Value Count'].sum()/df.shape[0]),2))
# Out:
# Total Records Present:  8790
#           Missing Value Count  Percentage
# director                 2621       29.82
# country                   829        9.43
# cast                      825        9.39
# Total                    4275       48.63

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8790 non-null   object
#  1   title         8790 non-null   object
#  2   director      6169 non-null   object
#  3   cast          7965 non-null   object
#  4   country       7961 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   genre         8790 non-null   object
#  10  description   8790 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 824.1+ KB

# %% [markdown]
# Converting the date added column from object to datetime format

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8790 entries, 0 to 8806
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8790 non-null   object
#  1   title         8790 non-null   object
#  2   director      6169 non-null   object
#  3   cast          7965 non-null   object
#  4   country       7961 non-null   object
#  5   date_added    8702 non-null   datetime64[ns]
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   genre         8790 non-null   object
#  10  description   8790 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(9)
# memory usage: 824.1+ KB

# %%
df['day'] = df['date_added'].dt.day
df['month'] = df['date_added'].dt.month
df['year'] = df['date_added'].dt.year
df['month_name'] = df['date_added'].dt.month_name()
df['weekday'] = df['date_added'].dt.day_name()
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description   day  month    year  \
# 0  As her father nears the end of his life, filmm...  25.0    9.0  2021.0
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  To protect his family from a powerful drug lor...  24.0    9.0  2021.0
# 3  Feuds, flirtations and toilet talk go down amo...  24.0    9.0  2021.0
# 4  In a city of coaching centers known to train I...  24.0    9.0  2021.0
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %% [markdown]
# Checking for unique values of rating and categorising them for better understanding

# %%
df['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['rating'] = df['rating'].replace(['TV-Y','TV-Y7','G','TV-G','PG','TV-PG','TV-Y7-FV'],'Kids')
df['rating'] = df['rating'].replace(['PG-13','TV-14'],'Teens')
df['rating'] = df['rating'].replace(['R','TV-MA','NC-17'],'Adults')
df['rating'] = df['rating'].replace(['NR','UR'],np.NaN)
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year  rating   duration  \
# 0 2021-09-25          2020   Teens     90 min
# 1 2021-09-24          2021  Adults  2 Seasons
# 2 2021-09-24          2021  Adults   1 Season
# 3 2021-09-24          2021  Adults   1 Season
# 4 2021-09-24          2021  Adults  2 Seasons
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description   day  month    year  \
# 0  As her father nears the end of his life, filmm...  25.0    9.0  2021.0
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  To protect his family from a powerful drug lor...  24.0    9.0  2021.0
# 3  Feuds, flirtations and toilet talk go down amo...  24.0    9.0  2021.0
# 4  In a city of coaching centers known to train I...  24.0    9.0  2021.0
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %%
df['rating'].unique()
# Out:
# array(['Teens', 'Adults', 'Kids', nan], dtype=object)

# %% [markdown]
# From here it is confirmed that values have been replaced successfully and now we will delete rows that have null values

# %%
df['rating'].isna().sum()
# Out:
# 82

# %%
df.dropna(subset = ['rating'],inplace=True)
df['rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# 82 values were null, whhich was only about 1% of the data, so we deleted those rows.

# %%
null = df.isna().sum().sort_values(ascending=False)
percent = round(df.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                  ',missing_data['Missing Value Count'].sum(),'     ',round(100*(missing_data['Missing Value Count'].sum()/df.shape[0]),2))
# Out:
# Total Records Present:  8708
#             Missing Value Count  Percentage
# director                   2617       30.05
# country                     829        9.52
# cast                        808        9.28
# date_added                   87        1.00
# day                          87        1.00
# month                        87        1.00
# year                         87        1.00
# month_name                   87        1.00
# weekday                      87        1.00
# Total                    4776       54.85

# %% [markdown]
# Now, we still have about 48% missing data. So, we will check in which rows the director, country and cast all three are null, if all these 3 are null then there is no use of that row.

# %%
df[(df['director'].isna()) & (df['country'].isna()) & (df['cast'].isna())].shape[0]
# Out:
# 96

# %% [markdown]
# We found out that total 96 such rows are there which dont have director, country and cast as null, so deleting those rows.

# %%
df.shape
# Out:
# (8708, 16)

# %%
df.dropna(subset = ['director','country','cast'], how = 'all',inplace=True)
df.shape
# Out:
# (8612, 16)

# %%
null = df.isna().sum().sort_values(ascending=False)
percent = round(df.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                  ',missing_data['Missing Value Count'].sum(),'     ',round(100*(missing_data['Missing Value Count'].sum()/df.shape[0]),2))
# Out:
# Total Records Present:  8612
#             Missing Value Count  Percentage
# director                   2521       29.27
# country                     733        8.51
# cast                        712        8.27
# date_added                   87        1.01
# day                          87        1.01
# month                        87        1.01
# year                         87        1.01
# month_name                   87        1.01
# weekday                      87        1.01
# Total                    4488       52.11

# %% [markdown]
# As the missing value percentage of these rows are significant, we cant delete them so we will deal with those later and now lets focus
#
# on one more major problem in the dataset which is NESTED DATA in director, cast, country, and genre.

# %%
df.head()
# Out:
#       type                 title         director  \
# 0    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show         Blood & Water              NaN
# 2  TV Show             Ganglands  Julien Leclercq
# 4  TV Show          Kota Factory              NaN
# 5  TV Show         Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...            NaN
#
#   date_added  release_year  rating   duration  \
# 0 2021-09-25          2020   Teens     90 min
# 1 2021-09-24          2021  Adults  2 Seasons
# 2 2021-09-24          2021  Adults   1 Season
# 4 2021-09-24          2021  Adults  2 Seasons
# 5 2021-09-24          2021  Adults   1 Season
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 4  International TV Shows, Romantic TV Shows, TV ...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description   day  month    year  \
# 0  As her father nears the end of his life, filmm...  25.0    9.0  2021.0
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  To protect his family from a powerful drug lor...  24.0    9.0  2021.0
# 4  In a city of coaching centers known to train I...  24.0    9.0  2021.0
# 5  The arrival of a charismatic young priest brin...  24.0    9.0  2021.0
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 4  September    Friday
# 5  September    Friday

# %% [markdown]
# Now we will split all the nested data individually and save them in a new dataframe, and then we will merge all of them so get the final dataframe.

# %% [markdown]
# In the process we will lose the format of null values from np.NaN to string NaN, so that requires one additional step which is done in the last 2 lines of each block We can confirm the count of null values from the above block

# %%
df_cast = pd.DataFrame(df['cast'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_cast = df_cast.stack()
df_cast = pd.DataFrame(df_cast)
df_cast.reset_index(inplace=True)
df_cast = df_cast[['title',0]]
df_cast.columns =['title','cast']
df_cast.replace('nan',np.NaN,inplace=True)
df_cast.isna().sum()
# Out:
# title      0
# cast     712
# dtype: int64

# %%
df_genre = pd.DataFrame(df['genre'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_genre = df_genre.stack()
df_genre = pd.DataFrame(df_genre)
df_genre.reset_index(inplace=True)
df_genre = df_genre[['title',0]]
df_genre.columns =['title','genre']
df_genre.replace('nan',np.NaN,inplace=True)
df_genre.isna().sum()
# Out:
# title    0
# genre    0
# dtype: int64

# %%
df_director = pd.DataFrame(df['director'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_director = df_director.stack()
df_director = pd.DataFrame(df_director)
df_director.reset_index(inplace=True)
df_director = df_director[['title',0]]
df_director.columns =['title','director']
df_director.replace('nan',np.NaN,inplace=True)
df_director.isna().sum()
# Out:
# title          0
# director    2521
# dtype: int64

# %%
df_country = pd.DataFrame(df['country'].apply(lambda x: str(x).split(', ')).tolist(),index=df['title'])
df_country = df_country.stack()
df_country = pd.DataFrame(df_country)
df_country.reset_index(inplace=True)
df_country = df_country[['title',0]]
df_country.columns =['title','country']
df_country.replace('nan',np.NaN,inplace=True)
df_country.isna().sum()
# Out:
# title        0
# country    733
# dtype: int64

# %%
df12 = df_cast.merge(df_genre, on = 'title')
df12
# Out:
#                        title                   cast                   genre
# 0       Dick Johnson Is Dead                    NaN           Documentaries
# 1              Blood & Water             Ama Qamata  International TV Shows
# 2              Blood & Water             Ama Qamata               TV Dramas
# 3              Blood & Water             Ama Qamata            TV Mysteries
# 4              Blood & Water            Khosi Ngema  International TV Shows
# ...                      ...                    ...                     ...
# 147927                Zubaan         Anita Shabdish    International Movies
# 147928                Zubaan         Anita Shabdish        Music & Musicals
# 147929                Zubaan  Chittaranjan Tripathy                  Dramas
# 147930                Zubaan  Chittaranjan Tripathy    International Movies
# 147931                Zubaan  Chittaranjan Tripathy        Music & Musicals
#
# [147932 rows x 3 columns]

# %%
df123 = df_director.merge(df12, on = 'title')
df123
# Out:
#                        title         director                   cast  \
# 0       Dick Johnson Is Dead  Kirsten Johnson                    NaN
# 1              Blood & Water              NaN             Ama Qamata
# 2              Blood & Water              NaN             Ama Qamata
# 3              Blood & Water              NaN             Ama Qamata
# 4              Blood & Water              NaN            Khosi Ngema
# ...                      ...              ...                    ...
# 159583                Zubaan      Mozez Singh         Anita Shabdish
# 159584                Zubaan      Mozez Singh         Anita Shabdish
# 159585                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 159586                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 159587                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          genre
# 0                Documentaries
# 1       International TV Shows
# 2                    TV Dramas
# 3                 TV Mysteries
# 4       International TV Shows
# ...                        ...
# 159583    International Movies
# 159584        Music & Musicals
# 159585                  Dramas
# 159586    International Movies
# 159587        Music & Musicals
#
# [159588 rows x 4 columns]

# %%
df1234 = df_country.merge(df123, on = 'title')
df1234
# Out:
#                        title        country         director  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 199945                Zubaan          India      Mozez Singh
# 199946                Zubaan          India      Mozez Singh
# 199947                Zubaan          India      Mozez Singh
# 199948                Zubaan          India      Mozez Singh
# 199949                Zubaan          India      Mozez Singh
#
#                          cast                   genre
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 199945         Anita Shabdish    International Movies
# 199946         Anita Shabdish        Music & Musicals
# 199947  Chittaranjan Tripathy                  Dramas
# 199948  Chittaranjan Tripathy    International Movies
# 199949  Chittaranjan Tripathy        Music & Musicals
#
# [199950 rows x 5 columns]

# %%
df_new = df.merge(df1234, on = 'title')
df_new
# Out:
#            type                 title       director_x  \
# 0         Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1       TV Show         Blood & Water              NaN
# 2       TV Show         Blood & Water              NaN
# 3       TV Show         Blood & Water              NaN
# 4       TV Show         Blood & Water              NaN
# ...         ...                   ...              ...
# 199945    Movie                Zubaan      Mozez Singh
# 199946    Movie                Zubaan      Mozez Singh
# 199947    Movie                Zubaan      Mozez Singh
# 199948    Movie                Zubaan      Mozez Singh
# 199949    Movie                Zubaan      Mozez Singh
#
#                                                    cast_x      country_x  \
# 0                                                     NaN  United States
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 3       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 4       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...                                                   ...            ...
# 199945  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 199946  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 199947  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 199948  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 199949  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#        date_added  release_year  rating   duration  \
# 0      2021-09-25          2020   Teens     90 min
# 1      2021-09-24          2021  Adults  2 Seasons
# 2      2021-09-24          2021  Adults  2 Seasons
# 3      2021-09-24          2021  Adults  2 Seasons
# 4      2021-09-24          2021  Adults  2 Seasons
# ...           ...           ...     ...        ...
# 199945 2019-03-02          2015   Teens    111 min
# 199946 2019-03-02          2015   Teens    111 min
# 199947 2019-03-02          2015   Teens    111 min
# 199948 2019-03-02          2015   Teens    111 min
# 199949 2019-03-02          2015   Teens    111 min
#
#                                                 genre_x  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2       International TV Shows, TV Dramas, TV Mysteries
# 3       International TV Shows, TV Dramas, TV Mysteries
# 4       International TV Shows, TV Dramas, TV Mysteries
# ...                                                 ...
# 199945   Dramas, International Movies, Music & Musicals
# 199946   Dramas, International Movies, Music & Musicals
# 199947   Dramas, International Movies, Music & Musicals
# 199948   Dramas, International Movies, Music & Musicals
# 199949   Dramas, International Movies, Music & Musicals
#
#                                               description   day  month  \
# 0       As her father nears the end of his life, filmm...  25.0    9.0
# 1       After crossing paths at a party, a Cape Town t...  24.0    9.0
# 2       After crossing paths at a party, a Cape Town t...  24.0    9.0
# 3       After crossing paths at a party, a Cape Town t...  24.0    9.0
# 4       After crossing paths at a party, a Cape Town t...  24.0    9.0
# ...                                                   ...   ...    ...
# 199945  A scrappy but poor boy worms his way into a ty...   2.0    3.0
# 199946  A scrappy but poor boy worms his way into a ty...   2.0    3.0
# 199947  A scrappy but poor boy worms his way into a ty...   2.0    3.0
# 199948  A scrappy but poor boy worms his way into a ty...   2.0    3.0
# 199949  A scrappy but poor boy worms his way into a ty...   2.0    3.0
#
#           year month_name   weekday      country_y       director_y  \
# 0       2021.0  September  Saturday  United States  Kirsten Johnson
# 1       2021.0  September    Friday   South Africa              NaN
# 2       2021.0  September    Friday   South Africa              NaN
# 3       2021.0  September    Friday   South Africa              NaN
# 4       2021.0  September    Friday   South Africa              NaN
# ...        ...        ...       ...            ...              ...
# 199945  2019.0      March  Saturday          India      Mozez Singh
# 199946  2019.0      March  Saturday          India      Mozez Singh
# 199947  2019.0      March  Saturday          India      Mozez Singh
# 199948  2019.0      March  Saturday          India      Mozez Singh
# 199949  2019.0      March  Saturday          India      Mozez Singh
#
#                        cast_y                 genre_y
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 199945         Anita Shabdish    International Movies
# 199946         Anita Shabdish        Music & Musicals
# 199947  Chittaranjan Tripathy                  Dramas
# 199948  Chittaranjan Tripathy    International Movies
# 199949  Chittaranjan Tripathy        Music & Musicals
#
# [199950 rows x 20 columns]

# %%
df_new.drop(columns = ['cast_x','country_x','director_x','genre_x'],inplace=True)
df_new.rename(columns={'country_y':'country','director_y':'director','cast_y':'cast','genre_y':'genre'},inplace=True)
df_new.head()
# Out:
#       type                 title date_added  release_year  rating   duration  \
# 0    Movie  Dick Johnson Is Dead 2021-09-25          2020   Teens     90 min
# 1  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 2  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 3  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 4  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
#
#                                          description   day  month    year  \
# 0  As her father nears the end of his life, filmm...  25.0    9.0  2021.0
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 3  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 4  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
#
#   month_name   weekday        country         director         cast  \
# 0  September  Saturday  United States  Kirsten Johnson          NaN
# 1  September    Friday   South Africa              NaN   Ama Qamata
# 2  September    Friday   South Africa              NaN   Ama Qamata
# 3  September    Friday   South Africa              NaN   Ama Qamata
# 4  September    Friday   South Africa              NaN  Khosi Ngema
#
#                     genre
# 0           Documentaries
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows

# %%
df_new.shape
# Out:
# (199950, 16)

# %% [markdown]
# This is the new dataframe which has 199950 rows and 16 columns after unnesting the data

# %%
null = df_new.isna().sum().sort_values(ascending=False)
percent = round(df_new.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df_new.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                 ',missing_data['Missing Value Count'].sum(),'     ',round(100*(missing_data['Missing Value Count'].sum()/df_new.shape[0]),2))
# Out:
# Total Records Present:  199950
#             Missing Value Count  Percentage
# director                  50116       25.06
# country                   11710        5.86
# cast                       1894        0.95
# date_added                 1546        0.77
# day                        1546        0.77
# month                      1546        0.77
# year                       1546        0.77
# month_name                 1546        0.77
# weekday                    1546        0.77
# Total                   72996       36.51

# %% [markdown]
# Here we will not delete the missing values as it will affect the data and other columns will get manipulated, hence we will replace them with a global value 'unknown'

# %%
df_new['cast'] = df_new['cast'].replace(np.NaN,'Unknown')
df_new['country'] = df_new['country'].replace(np.NaN,'Unknown')
df_new['director'] = df_new['director'].replace(np.NaN,'Unknown')

# %%
df_new.head()
# Out:
#       type                 title date_added  release_year  rating   duration  \
# 0    Movie  Dick Johnson Is Dead 2021-09-25          2020   Teens     90 min
# 1  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 2  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 3  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
# 4  TV Show         Blood & Water 2021-09-24          2021  Adults  2 Seasons
#
#                                          description   day  month    year  \
# 0  As her father nears the end of his life, filmm...  25.0    9.0  2021.0
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 3  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 4  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
#
#   month_name   weekday        country         director         cast  \
# 0  September  Saturday  United States  Kirsten Johnson      Unknown
# 1  September    Friday   South Africa          Unknown   Ama Qamata
# 2  September    Friday   South Africa          Unknown   Ama Qamata
# 3  September    Friday   South Africa          Unknown   Ama Qamata
# 4  September    Friday   South Africa          Unknown  Khosi Ngema
#
#                     genre
# 0           Documentaries
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows

# %%
null = df_new.isna().sum().sort_values(ascending=False)
percent = round(df_new.isna().mean()*100,2).sort_values(ascending = False)

missing_data = pd.concat([null,percent],axis=1,keys=['Missing Value Count','Percentage'])

print('Total Records Present: ',df_new.shape[0])
print(missing_data[missing_data['Missing Value Count']!=0])
print('Total','                 ',missing_data['Missing Value Count'].sum(),'     ',round(100*(missing_data['Missing Value Count'].sum()/df_new.shape[0]),2))
# Out:
# Total Records Present:  199950
#             Missing Value Count  Percentage
# date_added                 1546        0.77
# day                        1546        0.77
# month                      1546        0.77
# year                       1546        0.77
# month_name                 1546        0.77
# weekday                    1546        0.77
# Total                   9276       4.64

# %% [markdown]
# After replacing we can confirm no more null values

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199950 entries, 0 to 199949
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   type          199950 non-null  object
#  1   title         199950 non-null  object
#  2   date_added    198404 non-null  datetime64[ns]
#  3   release_year  199950 non-null  int64
#  4   rating        199950 non-null  object
#  5   duration      199950 non-null  object
#  6   description   199950 non-null  object
#  7   day           198404 non-null  float64
#  8   month         198404 non-null  float64
#  9   year          198404 non-null  float64
#  10  month_name    198404 non-null  object
#  11  weekday       198404 non-null  object
#  12  country       199950 non-null  object
#  13  director      199950 non-null  object
#  14  cast          199950 non-null  object
#  15  genre         199950 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(11)
# memory usage: 24.4+ MB

# %% [markdown]
# In the new dataframe, we can see 55 rows which are duplicated, so deleting them.

# %%
df_new.duplicated().sum()
# Out:
# 55

# %%
df_new.drop_duplicates(keep='first',inplace=True)

# %%
df_new.shape
# Out:
# (199895, 16)

# %% [markdown]
# Creating 2 more dataframes for better analysis by dividing the present dataframe on the basis of type i.e Movie and TV Show and naming them df_movies and df_tvs.

# %%
df_movies = df_new.loc[df_new['type']=='Movie']
df_tvs = df_new.loc[df_new['type']=='TV Show']

# %%
df_movies.shape
# Out:
# (144240, 16)

# %%
df_tvs.shape
# Out:
# (55655, 16)

# %% [markdown]
# The duration column has values such as 90 minutes for movies and 2 seasons for tv shows, so we will remove the word 'minutes' and 'seasons' in their respective dataframes.

# %%
df_movies['duration'] = df_movies['duration'].str.replace('min',"")
df_movies.head()
# Out:
# C:\Users\rauta\AppData\Local\Temp\ipykernel_17944\772087966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies['duration'] = df_movies['duration'].str.replace('min',"")
#       type                             title date_added  release_year rating  \
# 0    Movie              Dick Johnson Is Dead 2021-09-25          2020  Teens
# 157  Movie  My Little Pony: A New Generation 2021-09-24          2021   Kids
# 158  Movie  My Little Pony: A New Generation 2021-09-24          2021   Kids
# 159  Movie  My Little Pony: A New Generation 2021-09-24          2021   Kids
# 160  Movie  My Little Pony: A New Generation 2021-09-24          2021   Kids
#
#     duration                                        description   day  month  \
# 0        90   As her father nears the end of his life, filmm...  25.0    9.0
# 157      91   Equestria's divided. But a bright-eyed hero be...  24.0    9.0
# 158      91   Equestria's divided. But a bright-eyed hero be...  24.0    9.0
# 159      91   Equestria's divided. But a bright-eyed hero be...  24.0    9.0
# 160      91   Equestria's divided. But a bright-eyed hero be...  24.0    9.0
#
#        year month_name   weekday        country         director  \
# 0    2021.0  September  Saturday  United States  Kirsten Johnson
# 157  2021.0  September    Friday        Unknown    Robert Cullen
# 158  2021.0  September    Friday        Unknown    Robert Cullen
# 159  2021.0  September    Friday        Unknown    Robert Cullen
# 160  2021.0  September    Friday        Unknown    Robert Cullen
#
#                 cast                     genre
# 0            Unknown             Documentaries
# 157  Vanessa Hudgens  Children & Family Movies
# 158     Kimiko Glenn  Children & Family Movies
# 159    James Marsden  Children & Family Movies
# 160     Sofia Carson  Children & Family Movies

# %%
df_tvs['duration'] = df_tvs['duration'].str.replace('Seasons',"")
df_tvs['duration'] = df_tvs['duration'].str.replace('Season',"")
df_tvs.head()
# Out:
# C:\Users\rauta\AppData\Local\Temp\ipykernel_13108\4164884425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs['duration'] = df_tvs['duration'].str.replace('Seasons',"")
# C:\Users\rauta\AppData\Local\Temp\ipykernel_13108\4164884425.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs['duration'] = df_tvs['duration'].str.replace('Season',"")
#       type          title date_added  release_year  rating duration  \
# 1  TV Show  Blood & Water 2021-09-24          2021  Adults       2
# 2  TV Show  Blood & Water 2021-09-24          2021  Adults       2
# 3  TV Show  Blood & Water 2021-09-24          2021  Adults       2
# 4  TV Show  Blood & Water 2021-09-24          2021  Adults       2
# 5  TV Show  Blood & Water 2021-09-24          2021  Adults       2
#
#                                          description   day  month    year  \
# 1  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 2  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 3  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 4  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
# 5  After crossing paths at a party, a Cape Town t...  24.0    9.0  2021.0
#
#   month_name weekday       country director         cast  \
# 1  September  Friday  South Africa  Unknown   Ama Qamata
# 2  September  Friday  South Africa  Unknown   Ama Qamata
# 3  September  Friday  South Africa  Unknown   Ama Qamata
# 4  September  Friday  South Africa  Unknown  Khosi Ngema
# 5  September  Friday  South Africa  Unknown  Khosi Ngema
#
#                     genre
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows
# 5               TV Dramas

# %% [markdown]
# Here, we are replacing the column duration with a better name season for tv shows only in df_tvs.

# %%
df_tvs.rename(columns={'duration':'seasons'},inplace=True)
# Out:
# C:\Users\rauta\AppData\Local\Temp\ipykernel_17944\3221938497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs.rename(columns={'duration':'seasons'},inplace=True)

# %%
Finally, we have 4 dataframes, we will use all of these according to the analysis required ahead.

df = Cleaned data before unnesting.

df_new = Cleaned data after unnesting.

df_movies = Cleaned data of type - movie after unnesting.

df_tvs = Cleaned data of type - TV Show after unnesting.

# %%
We are ready with out dataframes, and also ready to begin our EDA!

# %%
Lets start with checking the time period of our data.

# %%
print(df['year'].min())
print(df['year'].max())
# Out:
# 2008.0
# 2021.0

# %%
The data lies between the year 2008 and 2021.
Now lets see the count of content available on Netflix.

# %%
df.shape[0]
# Out:
# 8612

# %%
The Netflix library has 8612 movies or shows to watch.

# %%
Now, lets see the count of movies and TV Shows individually.

# %%
print('Movie: ', df[df['type']=='Movie'].shape[0])
print('TV Show: ', df[df['type']=='TV Show'].shape[0])
# Out:
# Movie:  6031
# TV Show:  2581

# %%
There are a total of 6031 movies and 2581 TV shows to available.
Now, lets see how many directors are present in the data.

# %%
df_director['director'].nunique()
# Out:
# 4925

# %%
There are a total of 4925 directors present in the data.

# %%
Now, lets see the count of actors present.

# %%
df_cast['cast'].nunique()
# Out:
# 36148

# %%
There are a total of 36148 actors present in the data.
Lets check in how many countries in the data distributed in.

# %%
df_country['country'].nunique()
# Out:
# 127

# %%
The content is distributed across 127 countries.

# %%
Data Visualization

# %%
labels = ['Movie', 'TV Show']
plt.pie(df.groupby('type')['type'].count(), labels = labels, explode = (0.08,0), autopct = '%0.0f%%')
plt.suptitle('Movies vs TV Shows distribution')
plt.show()

# %%
df_temp = df_new.drop_duplicates(subset = ['country', 'title'])

x = df_temp['country'].value_counts().head(10)

plt.figure(figsize = (17,8))
plt.title('Content across Countries')
label = sns.countplot(data = df_temp, x = 'country', hue = 'type', order=x.index)
for i in label.containers:
    label.bar_label(i)
plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['director','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['director','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 Directors')

plt.subplot(1,2,1)
label = sns.countplot(data=df_movies_temp, x='director', order = df_movies_temp['director'].value_counts()[1:12].index)
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('Directors')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
label = sns.countplot(data=df_tvs_temp, x='director', order = df_tvs_temp['director'].value_counts()[1:12].index)
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('Directors')
plt.ylabel('TV Show Count')

plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['genre','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['genre','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 Genres')

plt.subplot(1,2,1)
label = sns.countplot(data= df_movies_temp, x='genre', order = df_movies_temp['genre'].value_counts().head(10).index)
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('Genres')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
label = sns.countplot(data=df_tvs_temp, x='genre', order = df_tvs_temp['genre'].value_counts().head(10).index)
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('Genres')
plt.ylabel('TV Show Count')

plt.show()

# %%
df_temp = df_new.drop_duplicates(subset = ['genre','title'])

plt.figure(figsize = (17,8))
plt.xticks(rotation=90)
sns.countplot(data = df_temp, x='country', hue = 'type', dodge = False, order = df_temp['country'].value_counts().head(30).index)
plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['rating','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['rating','title'])

plt.figure(figsize = (12,6))
plt.suptitle('Classification of Content on Netflix')

plt.subplot(1,2,1)
plt.pie(df_movies_temp['rating'].value_counts(), labels = df_movies_temp['rating'].value_counts().index, autopct='%.0f%%', explode = (0.05,0.03,0.03), shadow = True)
plt.title('Movies')

plt.subplot(1,2,2)
plt.pie(df_tvs_temp['rating'].value_counts(), labels = df_tvs_temp['rating'].value_counts().index, autopct='%.0f%%', explode = (0.05,0.03,0.03), shadow = True)
plt.title('TV Shows')

plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['year','title'])


mv_year = df_movies_temp['year'].value_counts()
mv_year.sort_index(inplace=True)

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']
mv_month = df_movies_temp['month_name'].value_counts().loc[month_order]

day_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
mv_day = df_movies_temp['weekday'].value_counts().loc[day_order]


plt.figure(figsize=(17,8))
plt.suptitle('Movies added on Netflix')

plt.subplot(1,3,1)
label = sns.countplot(data=df_movies_temp, x='year', order = mv_year.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.title('Year wise')

plt.subplot(1,3,2)
label = sns.countplot(data=df_movies_temp, x='month_name', order = mv_month.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.title('Month wise')

plt.subplot(1,3,3)
label = sns.countplot(data=df_movies_temp, x='weekday', order = mv_day.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Weekday')
plt.title('Day wise')


plt.show()

# %%
df_tvs_temp = df_tvs.drop_duplicates(subset = ['year','title'])

tv_year = df_tvs_temp['year'].value_counts()
tv_year.sort_index(inplace=True)

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']
tv_month = df_tvs_temp['month_name'].value_counts().loc[month_order]

day_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
tv_day = df_tvs_temp['weekday'].value_counts().loc[day_order]


plt.figure(figsize=(17,8))
plt.suptitle('TV Shows added on Netflix')

plt.subplot(1,3,1)
label = sns.countplot(data=df_tvs_temp, x='year', order = tv_year.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.title('Year wise')

plt.subplot(1,3,2)
label = sns.countplot(data=df_tvs_temp, x='month_name', order = tv_month.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.title('Month wise')

plt.subplot(1,3,3)
label = sns.countplot(data=df_tvs_temp, x='weekday', order = tv_day.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Weekday')
plt.title('Day wise')


plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['duration','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['seasons','title'])


plt.figure(figsize=(17,8))
plt.suptitle('Average Duration and Seasons of Content on Netflix')

plt.subplot(1,2,1)
label = sns.histplot(df_movies_temp['duration'].astype(int), bins=10, kde = True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel('Duration')
plt.title('Movies')

plt.subplot(1,2,2)
label = sns.histplot(df_tvs_temp['seasons'].astype(int), bins=10, kde = True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel('Seasons')
plt.title('TV Shows')

plt.show()

# %%
df_movies_temp['duration'] = df_movies_temp['duration'].astype(int)
df_tvs_temp['seasons'] = df_tvs_temp['seasons'].astype(int)

plt.figure(figsize=(17,8))
plt.suptitle('Average Duration and Seasons of Content on Netflix')

plt.subplot(1,2,1)
sns.boxplot(df_movies_temp, x='type', y='duration')
plt.title('Movies')

plt.subplot(1,2,2)
sns.boxplot(df_tvs_temp, x='type', y='seasons')
plt.title('TV Shows')

plt.show()
# Out:
# C:\Users\rauta\AppData\Local\Temp\ipykernel_17944\785406378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies_temp['duration'] = df_movies_temp['duration'].astype(int)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 2
#       1 df_movies_temp['duration'] = df_movies_temp['duration'].astype(int)
# ----> 2 df_tvs_temp['seasons'] = df_tvs_temp['seasons'].astype(int)
#       4 plt.figure(figsize=(17,8))
#       5 plt.suptitle('Average Duration and Seasons of Content on Netflix')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '2 Seasons'

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['cast','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['cast','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 Actors')

plt.subplot(1,2,1)
label = sns.countplot(data=df_movies_temp, x='cast', order = df_movies_temp['cast'].value_counts()[1:11].index)
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('Actors')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
label = sns.countplot(data=df_tvs_temp, x='cast', order = df_tvs_temp['cast'].value_counts()[1:11].index)
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('Actors')
plt.ylabel('TV Show Count')

plt.show()

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordgenre_text = " ".join(df_movies["genre"])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(wordgenre_text)

plt.figure(figsize=(17, 10))

plt.subplot(1,2,1)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Movie Genres Word Cloud")

genre_text = " ".join(df_tvs["genre"])
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(wordgenre_text)

plt.subplot(1,2,2)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("TV Shows Genres Word Cloud")

plt.show()

# %%
df_temp = df_new.drop_duplicates(subset = ['genre','title'])

plt.figure(figsize=(17,8))
plt.title('Distibution of rating among genres')
sns.countplot(data=df_temp, x='genre', hue = 'rating', dodge=False, order = df_temp['genre'].value_counts().index, palette='rocket')
plt.xticks(rotation=90)
plt.show()

# %%
df_temp = df_new.drop_duplicates(subset = ['country','title'])

plt.figure(figsize=(17,8))
plt.title('Distibution of genres among countries')
sns.countplot(data=df_temp, x='country', hue = 'genre', dodge=False, order = df_temp['country'].value_counts().head(20).index, palette='Paired')
plt.xticks(rotation=90)
plt.show()

# %%
df_temp = df_new.drop_duplicates(subset = ['country','title'])

plt.figure(figsize=(17,8))
plt.title('Distribution of rating among countries')
sns.countplot(data=df_temp, x='country', hue = 'rating', dodge=False, order = df_temp['country'].value_counts().head(20).index, palette='Paired')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Business Insights:
# 1)Netflix has 70% of its content as movies.
#   TV Shows are clearly lesser than Movies.
# 2)US has the most content for movies followed by India and UK. TV Shows are mostly created in the US and UK.
#   We can also observe that all the countries have more movies than TV Shows, whereas Jpaan and South Korea have more TV shows than movies.
# 3)Rajiv Chilaka, Jan Suter, Raul Campos are the most active directors with 22, 21 and 19 movies, whereas for TV Shows all the directos have
#   directed around 2-3 shows only.
# 4)Most of the content fall under International followed by Drama and Comedy genre.
# 5)Most content on Netflix is for the adults followed by Teens and Kids.
# 6)As per the data, most movies were released in the year 2019 and 2020. They were released the most in July. We can also see that most movies
#   were released on Friday.
# 7)As per the data, most TV Shows were released in the year 2019 and 2020. They were released the most in December followed by July and September.
#   We can also see that most shows were released on Friday.
# 8)Most (Around 4500) movies have duration between 65 and 125 minutes. Most(Around 2200) TV Shows have been produced for around 2 seasons.
# 9)The median duration of a movie on Netflix is around 100 minutes, whereas the median season of a TV Show is 1 season.
#   Most movies have duration length between 50 and 160 minutes. Most TV shows have either 1,2 or 3 seasons.
# 10)We can clearly see that Anupam Kher has done the most amount of movies followed by Shah Rukh Khan and Naseeruddin Shah.
# 11)The top 10 actors for movies are all Indians, whereas the top 10 actors for TV Shows are from different countries.
#    8 out of the top 10 actors for movies are males and 2 are females.
# 12)We can clearly see that most content(both movies and tv shows) are made for adults.
# 13)We can observe that International(Blue color) and Drama(Red color) are the most type of content available on Netflix.
# 14)We can see the in US and UK there is no content specially made for the teens, whereas in India we can see the that most of the content is
#    made for teens.

# %% [markdown]
# Recommendations:
#
# Here are some recommendations for each point:
#
# 1)Netflix has 70% of its content as movies. TV Shows are clearly lesser than Movies.
#   a)Consider investing more in TV show productions to balance the content library and cater to a wider audience.
#   b)Analyze the popularity and engagement metrics of existing TV shows to understand audience preferences and tailor future productions accordingly.
# 2)US has the most content for movies followed by India and UK. TV Shows are mostly created in the US and UK. We can also observe that all the countries have more movies than TV Shows, whereas Japan and South Korea have more TV shows than movies.
#   a)Expand content acquisition efforts in regions like Japan and South Korea to acquire more TV shows from these markets.
#   b)Explore partnerships and co-productions in regions with lower content production to increase the diversity of content offerings.
# 3)Rajiv Chilaka, Jan Suter, Raul Campos are the most active directors with 22, 21 and 19 movies, whereas for TV Shows all the directors have directed around 2-3 shows only.
#   a)Encourage collaboration with directors who have a proven track record of successful movies to develop more original content.
#   b)Provide opportunities and incentives for TV show directors to pitch new ideas and develop more shows.
# 4)Most of the content falls under International followed by Drama and Comedy genres.
#   a)Continue investing in International content as it appeals to a global audience and provides diverse storytelling.
#   b)Experiment with different genres to cater to varied audience preferences and keep the content library fresh.
# 5)Most content on Netflix is for adults followed by Teens and Kids.
#   a)Develop more content specifically targeted at the teenage demographic to capture this growing audience segment.
#   b)Invest in creating educational and informative content for kids to attract families and increase engagement.
# 6)Most movies were released in the year 2019 and 2020. They were released the most in July. We can also see that most movies were released on Friday.
#   a)Analyze release patterns and identify optimal release dates to maximize viewership and minimize competition.
#   b)Consider releasing more movies during peak viewing seasons and on weekends to capitalize on leisure time.
# 7)Most TV Shows were released in the year 2019 and 2020. They were released the most in December followed by July and September. We can also see that most shows were released on Friday.
#   a)Utilize holiday seasons and festive periods for strategic TV show releases to attract more viewers.
#   b)Schedule promotional activities and marketing campaigns around release dates to generate buzz and increase anticipation.
# 8)Most (Around 4500) movies have duration between 65 and 125 minutes. Most (Around 2200) TV Shows have been produced for around 2 seasons.
#   a)Consider producing more movies within the 65-125 minutes duration range to align with audience preferences for movie length.
#   b)Explore opportunities to extend successful TV shows beyond 2 seasons to capitalize on established fan bases and maintain viewer interest.
# 9)The median duration of a movie on Netflix is around 100 minutes, whereas the median season of a TV Show is 1 season. Most movies have duration length between 50 and 160 minutes. Most TV shows have either 1, 2 or 3 seasons.
#   a)Focus on creating more content within the popular duration range for both movies and TV shows to optimize viewer engagement.
#   b)Analyze viewer retention and feedback to determine optimal season lengths for TV shows and adjust future productions accordingly.
# 10)We can clearly see that Anupam Kher has done the most amount of movies followed by Shah Rukh Khan and Naseeruddin Shah.
#   a)Explore collaboration opportunities with popular actors like Anupam Kher, Shah Rukh Khan, and Naseeruddin Shah to attract their fan base and enhance the appeal of Netflix originals.
# 11)The top 10 actors for movies are all Indians, whereas the top 10 actors for TV Shows are from different countries. 8 out of the top 10 actors for movies are males and 2 are females.
#   a)Diversify the talent pool by collaborating with actors from various countries and backgrounds to create more inclusive content.
#   b)Invest in promoting and featuring talented female actors to bridge the gender gap in the entertainment industry.
# 12)We can clearly see that most content (both movies and TV shows) is made for adults.
#   a)Develop more content targeted at specific age groups such as teens and kids to broaden the audience base and increase viewer engagement.
#   b)Explore niche content catering to specific interests and demographics within the adult audience segment.
# 13)We can observe that International (Blue color) and Drama (Red color) are the most types of content available on Netflix.
#   a)Leverage data insights to guide content acquisition and production decisions, focusing on genres with high viewer demand and engagement.
#   b)Experiment with new genres or sub-genres to diversify the content library and attract a wider audience.
# 14)We can see that in the US and UK, there is no content specially made for the teens, whereas in India we can see that most of the content is made for teens.
#   a)Tailor content offerings to match regional preferences and cultural nuances, ensuring that content resonates with local audiences.
#   b)Collaborate with regional filmmakers and production houses to create more region-specific content targeted at different age groups.
